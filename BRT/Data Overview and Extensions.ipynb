# %%
# Make Jupyter Notebook full screen 
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))

# %% [markdown]
# ## Objective:
#
# Pull in the data files from the Madison Open Data Portal and peek at what is in them. This notebook is a good reference to have open while working with the data.

# %% [markdown]
# ## Notes:
#
# #### Data Origins:
#
# - mmt_GTFS: http://transitdata.cityofmadison.com/GTFS/
# - Open data portal: https://data-cityofmadison.opendata.arcgis.com/
#
# <br/>
# <br/>
# <br/>
# Author: Megan Tabbutt <br/>
# Last Revised: 9_8_20

# %%
# Import statements:

import pandas as pd
import numpy as np
import datetime

# %%
# Local data paths:

GTFS_DATA_PATH = "mmt_gtfs/"
# import os; os.listdir(GTFS_DATA_PATH) # Peak whats in the directory

# %%
def getPandasDFCSV(path, file, sep=','):  
    """ Keyword Arg sep: deliminator used in txt file (default = ',')"""
    pandasDF = pd.read_csv(path +  file, sep=sep)
    return pandasDF

# %% [markdown]
# ### stop_times:

# %%
stop_times_df = getPandasDFCSV(GTFS_DATA_PATH, 'stop_times.txt')
stop_times_df.head(3)
#stop_times_df.info()
# Out:
#    trip_id  stop_sequence  stop_id  pickup_type  drop_off_type arrival_time  \
# 0  9999999              1     7605            0              1      5:27:00
# 1  9999999              2     7739            0              0      5:27:40
# 2  9999999              3     7119            0              0      5:28:33
#
#   departure_time  timepoint  stop_headsign  shape_dist_traveled
# 0        5:27:00          1  EAST TRANSFER               0.0249
# 1        5:27:40          0  EAST TRANSFER               0.2003
# 2        5:28:33          0  EAST TRANSFER               0.4352

# %% [markdown]
# ### trips:

# %%
trips_df = getPandasDFCSV(GTFS_DATA_PATH, 'trips.txt')
trips_df.head(3)
# Out:
#    route_id  route_short_name service_id  trip_id  \
# 0      9041                16     92_WKD  9999999
# 1      9028                 2     92_WKD  1007843
# 2      9028                 2     92_WKD  1007844
#
#                  trip_headsign  direction_id  direction_name  block_id  \
# 0                EAST TRANSFER             0   East Transfer    193133
# 1  NORTH TRANSFER: VIA SHERMAN             0  North Transfer    194263
# 2   NORTH TRANSFER: VIA FORDEM             0  North Transfer    194056
#
#    shape_id shape_code trip_type  trip_sort  wheelchair_accessible  \
# 0     55293       P16E         D      19620                      1
# 1     55156         2S         W      20100                      1
# 2     55154         2F         W      21600                      1
#
#    bikes_allowed
# 0              1
# 1              1
# 2              1

# %% [markdown]
# ### stops:

# %%
stops_df = getPandasDFCSV(GTFS_DATA_PATH, 'stops.txt')
stops_df.head(10)
#stops_df.info()
# Out:
#    stop_id stop_code                        stop_name  \
# 0     1110      1110        E Dayton & Wisconsin (WB)
# 1     1111      1111       W Doty & M L K Junior (EB)
# 2     1124      1124        S Fairchild & W Main (SB)
# 3     1135      1135       N Webster & E Mifflin (NB)
# 4     1140      1140    E Washington & N Webster (WB)
# 5     1146      1146  N Fairchild & W Washington (SB)
# 6     1155      1155          S Webster & E Main (NB)
# 7     1174      1174            W Dayton & State (WB)
# 8     1189      1189         E Doty & S Pinckney (EB)
# 9     4000      SoTP             South Transfer Point
#
#                                            stop_desc   stop_lat   stop_lon  \
# 0  This EVENT/DETOUR ONLY stop (#1110) is westbou...  43.076428 -89.385920
# 1  This EVENT/DETOUR ONLY stop (#1111) is eastbou...  43.072938 -89.382354
# 2  This EVENT/DETOUR ONLY stop (#1124) is southbo...  43.072467 -89.385273
# 3  This EVENT/DETOUR ONLY stop (#1135) is northbo...  43.077272 -89.383413
# 4  This EVENT/DETOUR ONLY stop (#1140) is westbou...  43.076390 -89.381930
# 5  This EVENT/DETOUR ONLY stop (#1146) is southbo...  43.073504 -89.386724
# 6  This EVENT/DETOUR ONLY stop (#1155) is northbo...  43.075579 -89.381192
# 7  This EVENT/DETOUR ONLY stop (#1174) is westbou...  43.075120 -89.387855
# 8  This EVENT/DETOUR ONLY stop (#1189) is eastbou...  43.074111 -89.380724
# 9  The South Transfer Point station is located at...  43.038957 -89.394651
#
#   agency_id jurisdiction_id  location_type  parent_station  relative_position  \
# 0       MMT            CMAD              0             NaN                  3
# 1       MMT            CMAD              0             NaN                  3
# 2       MMT            CMAD              0             NaN                  3
# 3       MMT            CMAD              0             NaN                  1
# 4       MMT            CMAD              0             NaN                  3
# 5       MMT            CMAD              0             NaN                  3
# 6       MMT            CMAD              0             NaN                  1
# 7       MMT            CMAD              0             NaN                  3
# 8       MMT            CMAD              0             NaN                  3
# 9       MMT            MTSM              1             NaN                  5
#
#    cardinal_direction  wheelchair_boarding        primary_street  \
# 0               270.0                    1              E Dayton
# 1                90.0                    1                W Doty
# 2               180.0                    1           S Fairchild
# 3                 0.0                    1             N Webster
# 4               270.0                    1          E Washington
# 5               180.0                    1           N Fairchild
# 6                 0.0                    1             S Webster
# 7               270.0                    1              W Dayton
# 8                90.0                    1                E Doty
# 9                 NaN                    1  South Transfer Point
#
#    address_range cross_location
# 0              2      Wisconsin
# 1              1   M L K Junior
# 2             98         W Main
# 3            101      E Mifflin
# 4            200      N Webster
# 5             50   W Washington
# 6             99         E Main
# 7            198          State
# 8            101     S Pinckney
# 9           2430         S Park

# %% [markdown]
# ### routes:

# %%
routes_df = getPandasDFCSV(GTFS_DATA_PATH, 'routes.txt')
routes_df.head(3)
# Out:
#    route_id  service_id agency_id  route_short_name  route_long_name  \
# 0      9027          92       MMT                 1              NaN
# 1      9028          92       MMT                 2              NaN
# 2      9029          92       MMT                 3              NaN
#
#   route_service_name                                         route_desc  \
# 0   OLD UNIV:CAP SQR  Weekday schedule trips suspended until further...
# 1   WEST TP:NORTH TP  Daily schedule trips operate regularly every 3...
# 2    WEST TP:EAST TP  Weekday schedule trips suspended until further...
#
#    route_type                                          route_url route_color  \
# 0           3  http://www.cityofmadison.com/metro/routes-sche...      E3D23E
# 1           3  http://www.cityofmadison.com/metro/routes-sche...      981F66
# 2           3  http://www.cityofmadison.com/metro/routes-sche...      CD8382
#
#   route_text_color  bikes_allowed
# 0           000000              1
# 1           FFFFFF              1
# 2           000000              1

# %% [markdown]
# ***

# %% [markdown]
# # Extra Data from Analyses:

# %% [markdown]
# ## Trips that are being neglected b/c they happen past midnight
#
# Someone should go back in and fix those times to work with the functions.

# %%
arrivalTimesArray = np.array(stop_times_df['arrival_time'])

arrivalTimesArrayFixed = []
for time in arrivalTimesArray:
    timeList = time.split(":")
    timeList = [int(time) for time in timeList]
    if timeList[0] < 24:
        dateTime = datetime.datetime(2000, 1, 1, timeList[0], timeList[1], timeList[2])
    else:
        dateTime = datetime.datetime(2000, 1, 2, timeList[0]-24, timeList[1], timeList[2])
    arrivalTimesArrayFixed.append(dateTime)
    
stop_times_df['arrival_time'] = arrivalTimesArrayFixed
stop_times_df.head()
# Out:
#    trip_id  stop_sequence  stop_id  pickup_type  drop_off_type  \
# 0  9999999              1     7605            0              1
# 1  9999999              2     7739            0              0
# 2  9999999              3     7119            0              0
# 3  9999999              4     7107            0              0
# 4  9999999              5     7663            0              0
#
#          arrival_time departure_time  timepoint  stop_headsign  \
# 0 2000-01-01 05:27:00        5:27:00          1  EAST TRANSFER
# 1 2000-01-01 05:27:40        5:27:40          0  EAST TRANSFER
# 2 2000-01-01 05:28:33        5:28:33          0  EAST TRANSFER
# 3 2000-01-01 05:28:53        5:28:53          0  EAST TRANSFER
# 4 2000-01-01 05:29:51        5:29:51          0  EAST TRANSFER
#
#    shape_dist_traveled
# 0               0.0249
# 1               0.2003
# 2               0.4352
# 3               0.5255
# 4               0.7820

# %%
departureTimesArray = np.array(stop_times_df['departure_time'])

departureTimesArrayFixed = []
for time in departureTimesArray:
    timeList = time.split(":")
    timeList = [int(time) for time in timeList]
    if timeList[0] < 24:
        dateTime = datetime.datetime(2000, 1, 1, timeList[0], timeList[1], timeList[2])
    else:
        dateTime = datetime.datetime(2000, 1, 2, timeList[0]-24, timeList[1], timeList[2])
    departureTimesArrayFixed.append(dateTime)
    
stop_times_df['departure_time'] = departureTimesArrayFixed
stop_times_df.head()
# Out:
#    trip_id  stop_sequence  stop_id  pickup_type  drop_off_type  \
# 0  9999999              1     7605            0              1
# 1  9999999              2     7739            0              0
# 2  9999999              3     7119            0              0
# 3  9999999              4     7107            0              0
# 4  9999999              5     7663            0              0
#
#          arrival_time      departure_time  timepoint  stop_headsign  \
# 0 2000-01-01 05:27:00 2000-01-01 05:27:00          1  EAST TRANSFER
# 1 2000-01-01 05:27:40 2000-01-01 05:27:40          0  EAST TRANSFER
# 2 2000-01-01 05:28:33 2000-01-01 05:28:33          0  EAST TRANSFER
# 3 2000-01-01 05:28:53 2000-01-01 05:28:53          0  EAST TRANSFER
# 4 2000-01-01 05:29:51 2000-01-01 05:29:51          0  EAST TRANSFER
#
#    shape_dist_traveled
# 0               0.0249
# 1               0.2003
# 2               0.4352
# 3               0.5255
# 4               0.7820

# %%
# Out:
# datetime.datetime(2000, 1, 1, 5, 27, 40)
