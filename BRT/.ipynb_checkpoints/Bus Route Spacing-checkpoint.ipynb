# %%
# Make Jupyter Notebook full screen 
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))
# Out:
# <style>.container { width:80% !important; }</style>

# %% [markdown]
# ### Notes:
#
# - missing routes, see notes below, need to fix potentially
# - only considering weekday (not weekday standard)

# %%
# Import statements:

import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

# %%
# Local data paths:

GTFS_DATA_PATH = "mmt_gtfs/"
import os; os.listdir(GTFS_DATA_PATH) # Peak whats in the directory
# Out:
# ['fare_attributes.txt',
#  'transfers.txt',
#  'agency.txt',
#  'fare_rules.txt',
#  'calendar_dates.txt',
#  'stop_times.txt',
#  'shapes.txt',
#  'trips.txt',
#  'feed_info.txt',
#  'stops.txt',
#  'linked_datasets.txt',
#  'stop_features.txt',
#  'calendar.txt',
#  'routes.txt',
#  'translations.txt']

# %%
def getPandasDFCSV(path, file, sep=','):  
    """ Keyword Arg sep: deliminator used in txt file (default = ',')"""
    pandasDF = pd.read_csv(path +  file, sep=sep)
    return pandasDF

# %%
stop_times_df = getPandasDFCSV(GTFS_DATA_PATH, 'stop_times.txt')
#stop_times_df.info()
#stop_times_df.head(3)

# %%
trips_df = getPandasDFCSV(GTFS_DATA_PATH, 'trips.txt')
#trips_df.info()
#trips_df.head(3)

# %%
stops_df = getPandasDFCSV(GTFS_DATA_PATH, 'stops.txt')
#stops_df.info()
#stops_df.head(3)

# %% [markdown]
# Want to go through trips data to pull out a characteristic trip for each route, should be a trip with the maximum number of stops, could look at trips with the min later for comparison, or look at time variance later as well.

# %%
trips_df = getPandasDFCSV(GTFS_DATA_PATH, 'trips.txt')
#trips_df.info()
#trips_df.head(3)

# %%
# list of possible trips:

service_id_list = []

for i in trips_df['service_id']:
    if i not in service_id_list:
        service_id_list.append(i)
print(service_id_list)
# Out:
# ['92_WKD', '92_SAT', '92_SUN', '92_HOL', '92_MWK', '92_WKD:R', '92_SAT:R', '92_SUN:R', '92_HOL:R', '92_SAT:L', '92_SUN:L', '92_WKD:L#6', '92_WKD:L=6', '92_WKD:S', '92_SAT:S', '92_SUN:S', '92_WKD:S#6', '92_WKD:S=6']

# %%
# list of possible routes:

route_short_name_list = []

for i in trips_df['route_short_name']:
    if i not in route_short_name_list:
        route_short_name_list.append(i)

route_short_name_list.sort()
print(route_short_name_list)
# Out:
# [2, 4, 5, 6, 7, 8, 10, 11, 12, 13, 15, 16, 17, 18, 20, 21, 22, 23, 26, 27, 30, 31, 32, 33, 36, 39, 40, 44, 48, 49, 50, 51, 52, 55, 59, 63, 67, 68, 70, 72, 73, 75, 78, 80, 81, 82, 84]

# %% [markdown]
# 59, 63, 68, : weekend, holiday only
#
# 78: weekend only
#
# 80, 84 weekday standard

# %%
trips_df_weekday_peak = trips_df[trips_df['service_id'] == '92_WKD']
trips_df_weekday_peak_R = trips_df[trips_df['service_id'] == '92_WKD:R']
trips_df_weekday_peak_s = trips_df[trips_df['service_id'] == '92_WKD:L#6']
trips_df_weekday_peak_s3 = trips_df[trips_df['service_id'] == '92_WKD:L=6']
trips_df_weekday_peak_s1 = trips_df[trips_df['service_id'] == '92_WKD:S']
trips_df_weekday_peak_s2 = trips_df[trips_df['service_id'] == '92_WKD:S#6']
trips_df_weekday_peak_s4 = trips_df[trips_df['service_id'] == '92_WKD:S=6']

dfs_wk = [trips_df_weekday_peak, trips_df_weekday_peak_R, trips_df_weekday_peak_s, 
          trips_df_weekday_peak_s1, trips_df_weekday_peak_s2, trips_df_weekday_peak_s4]

trips_df_weekday = pd.concat(dfs_wk)
trips_df_weekday.head()
# Out:
#    route_id  route_short_name service_id  trip_id  \
# 0      9041                16     92_WKD  9999999
# 1      9028                 2     92_WKD  1007843
# 2      9028                 2     92_WKD  1007844
# 3      9028                 2     92_WKD  1007499
# 4      9028                 2     92_WKD  1007497
#
#                  trip_headsign  direction_id  direction_name  block_id  \
# 0                EAST TRANSFER             0   East Transfer    193133
# 1  NORTH TRANSFER: VIA SHERMAN             0  North Transfer    194263
# 2   NORTH TRANSFER: VIA FORDEM             0  North Transfer    194056
# 3  NORTH TRANSFER: VIA SHERMAN             0  North Transfer    194052
# 4   NORTH TRANSFER: VIA FORDEM             0  North Transfer    194058
#
#    shape_id shape_code trip_type  trip_sort  wheelchair_accessible  \
# 0     55293       P16E         D      19620                      1
# 1     55156         2S         W      20100                      1
# 2     55154         2F         W      21600                      1
# 3     55156         2S         D      23400                      1
# 4     55154         2F         D      25200                      1
#
#    bikes_allowed
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
routes_wk_list = []
for route in trips_df_weekday['route_short_name']:
    if route not in routes_wk_list:
        routes_wk_list.append(route)

routes_wk_list.sort()
print(routes_wk_list)
# Out:
# [2, 4, 5, 6, 7, 8, 10, 11, 12, 13, 15, 16, 17, 18, 20, 21, 22, 23, 26, 27, 30, 31, 32, 33, 36, 39, 40, 44, 48, 49, 50, 51, 52, 55, 67, 70, 72, 73, 75, 80, 81, 82, 84]

# %%
print("weekend and holiday routes:")
for route in route_short_name_list:
    if route not in routes_wk_list:
        print(route)
# Out:
# weekend and holiday routes:
# 59
# 63
# 68
# 78

# %%
# make a dictionary of routes with trip ID's for weekday service:

tripIDList_forRoutes_weekday92 = dict()

for i in routes_wk_list:
    trip_list = []
    for j in trips_df_weekday[trips_df_weekday['route_short_name'] == i].iterrows():
        trip_list.append(j[1]['trip_id'])
    tripIDList_forRoutes_weekday92[i] = trip_list

tripIDList_forRoutes_weekday92[23]
# Out:
# [1010783,
#  1010782,
#  1010781,
#  1010780,
#  1010779,
#  1010778,
#  1010777,
#  1010790,
#  1010789,
#  1010788,
#  1010787,
#  1010786,
#  1010785,
#  1010784]

# %%
for route in tripIDList_forRoutes_weekday92:
    
    for trip in tripIDList_forRoutes_weekday92[route]:
        trip_stop_time_df = stop_times_df[stop_times_df['trip_id'] == trip]

# %%
def get_stop_distances(trip):
    """ getting the stop spacing for a given trip. Stop spacing is defined as the distance travelled by bus between two cosecutive stops. 
    Should mirror natural walking terrain better than distance between two globe points.
    
    return: numpy array - contains # of stops - 1 elements that are the distances between stops driven by the bus
    """
    stop_dist_array = []
    trip_stop_time_df = stop_times_df[stop_times_df['trip_id'] == trip]
    distance_travelled = np.array(trip_stop_time_df['shape_dist_traveled'])
    for i in range(len(distance_travelled)-1):
        stop_spacing = distance_travelled[i+1] - distance_travelled[i]
        stop_dist_array.append(stop_spacing)
        
    return stop_dist_array

print(get_stop_distances(9999999))
# Out:
# [0.1754, 0.23489999999999997, 0.09029999999999999, 0.25650000000000006, 0.24869999999999992, 0.09620000000000006, 0.20589999999999997, 0.21829999999999994, 0.1684000000000001, 0.25239999999999996, 0.3065, 0.1383000000000001, 0.11730000000000018, 0.20689999999999964, 0.15210000000000035, 0.1325999999999996, 0.15980000000000016, 0.20020000000000016, 0.3004000000000002]

# %%
all_trip_distances_forRoutes_weekday92 = dict()

for route in tripIDList_forRoutes_weekday92:
    #print(route)
    all_trip_distances = []
    for trip in tripIDList_forRoutes_weekday92[route]:
        #print(trip)
        trip_distances = get_stop_distances(trip)
        all_trip_distances.append(trip_distances)
    all_trip_distances_forRoutes_weekday92[route] = all_trip_distances
    
#all_trip_distances_forRoutes_weekday92

# %%
all_trip_distances_forRoutes_weekday92 = dict()

for route in tripIDList_forRoutes_weekday92:
    #print(route)
    all_trip_distances = []
    for trip in tripIDList_forRoutes_weekday92[route]:
        #print(trip)
        trip_distances = get_stop_distances(trip)
        all_trip_distances += trip_distances
        all_trip_distances.sort()
    all_trip_distances_forRoutes_weekday92[route] = np.array(all_trip_distances)
    
#all_trip_distances_forRoutes_weekday92

# %%
weekday_routes_92_allTrips = pd.DataFrame.from_dict(dict([ (k, pd.Series(v)) for k, v in all_trip_distances_forRoutes_weekday92.items()]))
weekday_routes_92_allTrips
# Out:
#           2       4       5       6       7       8       10      11      12  \
# 0     0.0808  0.0659  0.0624  0.0719  0.0772  0.0704  0.0772  0.0703  0.0696
# 1     0.0808  0.0659  0.0624  0.0719  0.0772  0.0704  0.0772  0.0703  0.0696
# 2     0.0808  0.0659  0.0624  0.0719  0.0772  0.0704  0.0772  0.0703  0.0696
# 3     0.0808  0.0659  0.0624  0.0719  0.0772  0.0704  0.0772  0.0703  0.0696
# 4     0.0808  0.0659  0.0624  0.0719  0.0772  0.0704  0.0772  0.0809  0.0808
# ...      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 8825     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 8826     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 8827     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 8828     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 8829     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#           13  ...      55      67      70      72      73      75      80  \
# 0     0.0699  ...  0.2089  0.1274  0.0789  0.0808  0.0684  0.0624  0.0684
# 1     0.0699  ...  0.2089  0.1274  0.0789  0.0808  0.0684  0.0624  0.0684
# 2     0.0699  ...  0.2089  0.1274  0.0789  0.0808  0.0684  0.0624  0.0684
# 3     0.0699  ...  0.2089  0.1274  0.0789  0.0808  0.0684  0.0624  0.0684
# 4     0.0699  ...  0.2089  0.1274  0.0789  0.0808  0.0684  0.0624  0.0684
# ...      ...  ...     ...     ...     ...     ...     ...     ...     ...
# 8825     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN  0.3392
# 8826     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN  0.3392
# 8827     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN  0.3392
# 8828     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN  0.3392
# 8829     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN  0.3392
#
#           81    82      84
# 0     0.0907  0.08  0.0684
# 1     0.0907  0.08  0.0684
# 2     0.0907  0.08  0.0684
# 3     0.0907  0.08  0.0684
# 4     0.0907  0.08  0.0684
# ...      ...   ...     ...
# 8825     NaN   NaN     NaN
# 8826     NaN   NaN     NaN
# 8827     NaN   NaN     NaN
# 8828     NaN   NaN     NaN
# 8829     NaN   NaN     NaN
#
# [8830 rows x 43 columns]

# %%
list(weekday_routes_92_allTrips[23])
# Out:
# [0.1345,
#  0.1345,
#  0.1345,
#  0.1345,
#  0.1345,
#  0.1345,
#  0.1345,
#  0.1486,
#  0.1486,
#  0.1486,
#  0.1486,
#  0.1486,
#  0.1486,
#  0.1486,
#  0.1507000000000005,
#  0.1507000000000005,
#  0.1507000000000005,
#  0.15080000000000027,
#  0.15080000000000027,
#  0.15080000000000027,
#  0.15080000000000027,
#  0.15389999999999998,
#  0.15389999999999998,
#  0.15389999999999998,
#  0.15389999999999998,
#  0.15389999999999998,
#  0.15389999999999998,
#  0.15389999999999998,
#  0.155,
#  0.155,
#  0.155,
#  0.155,
#  0.155,
#  0.155,
#  0.155,
#  0.18420000000000059,
#  0.18420000000000059,
#  0.18420000000000059,
#  0.18420000000000059,
#  0.19620000000000104,
#  0.19620000000000104,
#  0.19620000000000104,
#  0.21760000000000002,
#  0.21760000000000002,
#  0.21760000000000002,
#  0.21760000000000002,
#  0.2178,
#  0.2178,
#  0.2178,
#  0.2373,
#  0.2373,
#  0.2373,
#  0.24389999999999978,
#  0.24389999999999978,
#  0.24389999999999978,
#  0.24389999999999978,
#  0.24399999999999977,
#  0.24399999999999977,
#  0.24399999999999977,
#  0.24650000000000105,
#  0.24650000000000105,
#  0.24650000000000105,
#  0.24650000000000105,
#  0.2794,
#  0.2794,
#  0.2794,
#  0.2794,
#  0.2865000000000002,
#  0.2865000000000002,
#  0.2865000000000002,
#  0.2865000000000002,
#  0.29069999999999996,
#  0.29069999999999996,
#  0.29069999999999996,
#  0.3024,
#  0.3024,
#  0.3024,
#  0.3024,
#  0.3064999999999998,
#  0.3064999999999998,
#  0.3064999999999998,
#  0.3064999999999998,
#  0.3110999999999997,
#  0.3110999999999997,
#  0.3110999999999997,
#  0.3110999999999997,
#  0.3138000000000001,
#  0.3138000000000001,
#  0.3138000000000001,
#  0.3138000000000001,
#  0.3151,
#  0.3151,
#  0.3151,
#  0.3151,
#  0.33590000000000053,
#  0.33590000000000053,
#  0.33590000000000053,
#  0.33590000000000053,
#  0.3371999999999993,
#  0.3371999999999993,
#  0.3371999999999993,
#  0.3371999999999993,
#  0.3422999999999998,
#  0.3422999999999998,
#  0.3422999999999998,
#  0.3573000000000004,
#  0.3573000000000004,
#  0.3573000000000004,
#  0.3573000000000004,
#  0.36660000000000004,
#  0.36660000000000004,
#  0.36660000000000004,
#  0.36710000000000065,
#  0.36710000000000065,
#  0.36710000000000065,
#  0.36710000000000065,
#  0.3868999999999989,
#  0.3868999999999989,
#  0.3868999999999989,
#  0.3868999999999989,
#  0.3941000000000001,
#  0.3941000000000001,
#  0.3941000000000001,
#  0.39590000000000014,
#  0.39590000000000014,
#  0.39590000000000014,
#  0.39590000000000014,
#  0.41810000000000014,
#  0.41810000000000014,
#  0.41810000000000014,
#  0.41810000000000014,
#  0.43180000000000085,
#  0.43180000000000085,
#  0.43180000000000085,
#  0.44510000000000005,
#  0.44510000000000005,
#  0.44510000000000005,
#  0.4456,
#  0.4456,
#  0.4456,
#  0.4456,
#  0.4456,
#  0.4456,
#  0.4456,
#  0.4545999999999992,
#  0.4545999999999992,
#  0.4545999999999992,
#  0.4545999999999992,
#  0.4644999999999999,
#  0.4644999999999999,
#  0.4644999999999999,
#  0.4644999999999999,
#  0.4698000000000011,
#  0.4698000000000011,
#  0.4698000000000011,
#  0.4698000000000011,
#  0.48229999999999995,
#  0.48229999999999995,
#  0.48229999999999995,
#  0.48229999999999995,
#  0.5179000000000009,
#  0.5179000000000009,
#  0.5179000000000009,
#  0.5179000000000009,
#  0.5179000000000009,
#  0.5179000000000009,
#  0.5179000000000009,
#  0.7639000000000005,
#  0.7639000000000005,
#  0.7639000000000005,
#  0.7639000000000005,
#  0.7639000000000005,
#  0.7639000000000005,
#  0.7639000000000005,
#  0.7651999999999992,
#  0.7651999999999992,
#  0.7651999999999992,
#  0.7652999999999999,
#  0.7652999999999999,
#  0.7652999999999999,
#  0.7652999999999999,
#  0.7950999999999997,
#  0.7950999999999997,
#  0.7950999999999997,
#  0.8187,
#  0.8187,
#  0.8187,
#  1.8621999999999996,
#  1.8621999999999996,
#  1.8621999999999996,
#  1.8621999999999996,
#  1.8622999999999994,
#  1.8622999999999994,
#  1.8622999999999994,
#  1.8939,
#  1.8939,
#  1.8939,
#  1.8939,
#  1.8939,
#  1.8939,
#  1.8939,
#  1.8963,
#  1.8963,
#  1.8963,
#  1.8963,
#  1.8963,
#  1.8963,
#  1.8963,
#  1.9222,
#  1.9222,
#  1.9222,
#  1.9222,
#  1.9222,
#  1.9222,
#  1.9222,
#  1.9610000000000003,
#  1.9610000000000003,
#  1.9610000000000003,
#  2.489399999999999,
#  2.489399999999999,
#  2.489399999999999,
#  3.5966999999999993,
#  3.5966999999999993,
#  3.5966999999999993,
#  3.5966999999999993,
#  3.8532999999999995,
#  3.8532999999999995,
#  3.8532999999999995,
#  3.8532999999999995,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  ...]

# %%
ax = plt.subplots(figsize=(20, 12))[1]

for i, col in enumerate(weekday_routes_92_allTrips.columns):
    s = weekday_routes_92_allTrips[col]
    x = i+1
    
    y = s.quantile(0.5)
    ax.plot(x, y, color='#b00149', linewidth=3, markersize=5, marker = "_", alpha=.9)

    y1 = s.quantile(0.75)
    y2 = s.quantile(1)
    ax.plot((x, x), (y1, y2), color='#87ae73', linewidth=5, markersize=1, linestyle = "-", alpha=.9)
    #ax.plot((x-.5, x+.5), (y1, y1), color='k', linewidth=2, markersize=1, linestyle = "-", alpha=.5)

    y1 = s.quantile(0)
    y2 = s.quantile(0.25)
    ax.plot((x, x), (y1, y2), color='#34013f', linewidth=5, markersize=1, linestyle = "-", alpha=.9)
    
ax.set_xlim(0.5, len(weekday_routes_92_allTrips.columns)+0.5)
ax.set_ylim(0, 4)
ax.set_xticklabels(list(weekday_routes_92_allTrips.columns))
ax.set_xticks(range(1, len(weekday_routes_92_allTrips.columns)+1))
    
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

plt.xlabel("Weekday Bus Routes")
plt.ylabel("Stop Distance (miles)")

custom_lines = [Line2D([0], [0], color='#b00149', lw=4), Line2D([0], [0], color='#87ae73', lw=4), Line2D([0], [0], color='#34013f', lw=4)]
plt.legend(custom_lines, ['Mean', 'Top 25%', 'Bottom 25%'])

plt.title("Quartiles and mean distance travelled for all weekday trips")
plt.savefig("Quartiles_allTrips_Weekdays")
# Out:
# <ipython-input-20-35336e855fe7>:21: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(list(weekday_routes_92_allTrips.columns))

# %%
ax = plt.subplots(figsize=(20, 10))[1]

for i, col in enumerate(weekday_routes_92_allTrips.columns):
    s = weekday_routes_92_allTrips[col]
    x = i+1
    
    #y = s.quantile(0.5)
    #ax.plot(x, y, color='#b00149', linewidth=3, markersize=5, marker = "_", alpha=.9)

    y1 = s.quantile(0.75)
    y2 = s.quantile(1)
    ax.plot((x, x), (y1, y2), color='#87ae73', linewidth=20, markersize=1, linestyle = "-", alpha=.7)
    #ax.plot((x-.5, x+.5), (y1, y1), color='k', linewidth=2, markersize=1, linestyle = "-", alpha=.5)

    y1 = s.quantile(0)
    y2 = s.quantile(0.25)
    ax.plot((x, x), (y1, y2), color='#34013f', linewidth=20, markersize=1, linestyle = "-", alpha=.7)
    
    y1 = s.quantile(0.25)
    y2 = s.quantile(0.75)
    ax.plot((x, x), (y1, y2), color='#b00149', linewidth=10, markersize=1, linestyle = "-", alpha=.7)
    
ax.set_xlim(0.5, len(weekday_routes_92_allTrips.columns)+0.5)
ax.set_ylim(0, 4)
ax.set_xticklabels(list(weekday_routes_92_allTrips.columns))
ax.set_xticks(range(1, len(weekday_routes_92_allTrips.columns)+1))
    
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

plt.xlabel("Weekday Bus Routes")
plt.ylabel("Stop Distance (miles)")

custom_lines = [Line2D([0], [0], color='#b00149', lw=4), Line2D([0], [0], color='#87ae73', lw=4), Line2D([0], [0], color='#34013f', lw=4)]
plt.legend(custom_lines, ['Middle 50%', 'Top 25%', 'Bottom 25%'])
# Out:
# <ipython-input-21-8d745b7396d8>:25: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(list(weekday_routes_92_allTrips.columns))

# %%
ax = plt.subplots(figsize=(20, 8))[1]

for i, col in enumerate(weekday_routes_92_allTrips.columns):
    s = weekday_routes_92_allTrips[col]
    x = i+1
    
    y = s.quantile(0.5)
    ax.plot(x, y, color='#b00149', linewidth=3, markersize=5, marker = "_", alpha=.9)

    y1 = s.quantile(0.75)
    y2 = s.quantile(1)
    ax.plot((x, x), (y1, y2), color='#87ae73', linewidth=5, markersize=1, linestyle = "-", alpha=.9)
    #ax.plot((x-.5, x+.5), (y1, y1), color='k', linewidth=2, markersize=1, linestyle = "-", alpha=.5)

    y1 = s.quantile(0)
    y2 = s.quantile(0.25)
    ax.plot((x, x), (y1, y2), color='#34013f', linewidth=5, markersize=1, linestyle = "-", alpha=.9)
    
ax.set_xlim(0.5, len(weekday_routes_92_allTrips.columns)+0.5)
ax.set_ylim(0, 1)
ax.set_xticklabels(list(weekday_routes_92_allTrips.columns))
ax.set_xticks(range(1, len(weekday_routes_92_allTrips.columns)+1))
    
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

plt.xlabel("Weekday Bus Routes")
plt.ylabel("Stop Distance (miles)")

custom_lines = [Line2D([0], [0], color='#b00149', lw=4), Line2D([0], [0], color='#87ae73', lw=4), Line2D([0], [0], color='#34013f', lw=4)]
plt.legend(custom_lines, ['Mean', 'Top 25%', 'Bottom 25%'])

plt.title("Quartiles and mean distance travelled for all weekday trips - Zoom")
plt.savefig("Quartiles_allTrips_Weekdays_zoom")
# Out:
# <ipython-input-22-e165bf8bab5c>:21: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(list(weekday_routes_92_allTrips.columns))

# %%
ax = plt.subplots(figsize=(20, 8))[1]

for i, col in enumerate(weekday_routes_92_allTrips.columns):
    s = weekday_routes_92_allTrips[col]
    x = i+1
    
    y1 = 0
    y2 = s.quantile(.5)
    ax.plot((x, x), (y1, y2), color='#34013f', linewidth=10, markersize=1, linestyle = "-", alpha=.9)
    
ax.set_xlim(0.5, len(weekday_routes_92_allTrips.columns)+0.5)
plt.ylim(0, .4)
ax.set_xticklabels(list(weekday_routes_92_allTrips.columns))
ax.set_xticks(range(1, len(weekday_routes_92_allTrips.columns)+1))
    
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

plt.xlabel("Weekday Bus Routes")
plt.ylabel("Stop Distance (miles)")

custom_lines = [Line2D([0], [0], color='#34013f', lw=4)]
plt.legend(custom_lines, ['Mean'])

plt.title("Mean distance travelled for all weekday trips")
plt.savefig("Means_allTrips_Weekdays_zoom")
# Out:
# <ipython-input-23-ac075a0712a4>:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(list(weekday_routes_92_allTrips.columns))

# %%
ax = plt.subplots(figsize=(20, 8))[1]

for i, col in enumerate(weekday_routes_92_allTrips.columns):
    s = weekday_routes_92_allTrips[col]
    x = i+1

    y1 = s.quantile(0)
    y2 = s.quantile(.20)
    ax.plot((x, x), (y1, y2), color='#87ae73', linewidth=5, markersize=1, linestyle = "-", alpha=.9)

    
ax.set_xlim(0.5, len(weekday_routes_92_allTrips.columns)+0.5)
ax.set_xticklabels(list(weekday_routes_92_allTrips.columns))
ax.set_xticks(range(1, len(weekday_routes_92_allTrips.columns)+1))
    
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

plt.xlabel("Weekday Bus Routes")
plt.ylabel("Stop Distance (miles)")

custom_lines = [Line2D([0], [0], color='#b00149', lw=4), Line2D([0], [0], color='#87ae73', lw=4), Line2D([0], [0], color='#34013f', lw=4)]
plt.legend(custom_lines, ['Mean', 'Top 25%', 'Bottom 25%'])

plt.title("Quartiles and mean distance travelled for all weekday trips - Zoom")
#plt.savefig("Quartiles_allTrips_Weekdays_zoom")
# Out:
# <ipython-input-36-1221b403ae98>:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(list(weekday_routes_92_allTrips.columns))
# Text(0.5, 1.0, 'Quartiles and mean distance travelled for all weekday trips - Zoom')
