# %%
# Make Jupyter Notebook full screen 
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
import geopandas
import pandas as pd
import matplotlib.pyplot as plt
import random
from mpl_toolkits.axes_grid1 import make_axes_locatable
import numpy as np

# %%
#DATA_PATH = '/Users/megantabbutt/BRT_data/GeoData/'
#DATA_PATH_Dems = '/Users/megantabbutt/BRT_data/DemographicData/'
RoutesShapeFile = "mmt_gtfs/Metro_Transit_Bus_Routes.shp"
CitiesShapeFile = "Shapes/City/City_Limit.shp"
LakesShapeFile = "Shapes/Lakes/Lakes_and_Rivers.shp"
StreetsShapeFile = "Shapes/Street/Street_Centerlines_and_Pavement_Data.shp"


cityShapes_df = geopandas.read_file(CitiesShapeFile)
lakeShapes_df = geopandas.read_file(LakesShapeFile)
streetShapes_df = geopandas.read_file(StreetsShapeFile)

# %%
DATA_PATH = '/Users/megantabbutt/BRT_data/GeoData/'
DATA_PATH_Dems = '/Users/megantabbutt/BRT_data/DemographicData/'

df = geopandas.read_file(DATA_PATH+"tl_2018_55_bg.shp")
df_dane = df[df['COUNTYFP'] == "025"]
df_dane.head(3)
# Out:
#     STATEFP COUNTYFP TRACTCE BLKGRPCE         GEOID       NAMELSAD  MTFCC  \
# 570      55      025  002000        1  550250020001  Block Group 1  G5030
# 577      55      025  001300        1  550250013001  Block Group 1  G5030
# 578      55      025  001401        1  550250014011  Block Group 1  G5030
#
#     FUNCSTAT    ALAND  AWATER     INTPTLAT      INTPTLON  \
# 570        S   607897    1617  +43.1040466  -089.3349658
# 577        S  1070101     503  +43.0541194  -089.3889560
# 578        S  2579158   42576  +43.0468061  -089.3795062
#
#                                               geometry
# 570  POLYGON ((-89.34179 43.10456, -89.34163 43.104...
# 577  POLYGON ((-89.40006 43.05842, -89.39907 43.058...
# 578  POLYGON ((-89.39403 43.04175, -89.39313 43.041...

# %%
df_mad = pd.read_csv(DATA_PATH_Dems + "Block_level_2018.txt", sep='\t')
df_mad.info()
df_mad.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 310 entries, 0 to 309
# Data columns (total 8 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   GEOID                            310 non-null    int64
#  1   Total                            310 non-null    int64
#  2   TotalInLaborForce                310 non-null    int64
#  3   LaborEmployed                    310 non-null    int64
#  4   LaborUnemployed                  310 non-null    int64
#  5   AggEarningsPast12MoInflationAdj  299 non-null    object
#  6   TotalBusToWork                   310 non-null    int64
#  7   TotalCarToWork                   310 non-null    int64
# dtypes: int64(7), object(1)
# memory usage: 19.5+ KB
#           GEOID  Total  TotalInLaborForce  LaborEmployed  LaborUnemployed  \
# 0  550250121001    543                413            400               13
# 1  550250127002   1482               1021           1008               13
# 2  550250121002    690                526            492               34
#
#   AggEarningsPast12MoInflationAdj  TotalBusToWork  TotalCarToWork
# 0                        21188300               0             355
# 1                        70886200               0             903
# 2                        27841100               0             446

# %%
geoIDs_Master = [int(i) for i in list(df_dane['GEOID'])]
type(geoIDs_Master[0])
# Out:
# int

# %%
df_dane.loc[df_dane['GEOID'] == '550250020001', 'ALAND'].item()
# Out:
# 607897

# %%
Population = dict()
for ID in geoIDs_Master:
    #madDF = df_mad[df_mad['GEOID'] == ID]
    #geoDF = df_dane[df_dane['GEOID'] == ID]
    totalPop = df_mad.loc[df_mad['GEOID'] == ID, 'Total'].item()
    totalland = df_dane.loc[df_dane['GEOID'] == str(ID), 'ALAND'].item() + df_dane.loc[df_dane['GEOID'] == str(ID), 'AWATER'].item()
    #print(totalPop, totalland)
    if totalland != 0 and totalPop !=0 :
        number = np.log(totalPop*100000/totalland)
    else:
        number = None
        
    Population[ID] = number
    
#Population

# %%
df_dane['Population'] = list(Population.values())
df_dane.head(3)
# Out:
# /Users/megantabbutt/Library/Python/3.8/lib/python/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
#     STATEFP COUNTYFP TRACTCE BLKGRPCE         GEOID       NAMELSAD  MTFCC  \
# 570      55      025  002000        1  550250020001  Block Group 1  G5030
# 577      55      025  001300        1  550250013001  Block Group 1  G5030
# 578      55      025  001401        1  550250014011  Block Group 1  G5030
#
#     FUNCSTAT    ALAND  AWATER     INTPTLAT      INTPTLON  \
# 570        S   607897    1617  +43.1040466  -089.3349658
# 577        S  1070101     503  +43.0541194  -089.3889560
# 578        S  2579158   42576  +43.0468061  -089.3795062
#
#                                               geometry  Population
# 570  POLYGON ((-89.34179 43.10456, -89.34163 43.104...    4.944779
# 577  POLYGON ((-89.40006 43.05842, -89.39907 43.058...    4.980992
# 578  POLYGON ((-89.39403 43.04175, -89.39313 43.041...    4.264595

# %%
routesShapes_df = geopandas.read_file(RoutesShapeFile)
routesShapes_df.info()
routesShapes_df.head(3)
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OBJECTID    47 non-null     int64
#  1   trips_rout  47 non-null     int64
#  2   route_shor  47 non-null     int64
#  3   route_url   47 non-null     object
#  4   ShapeSTLen  47 non-null     float64
#  5   geometry    47 non-null     geometry
# dtypes: float64(1), geometry(1), int64(3), object(1)
# memory usage: 2.3+ KB
#    OBJECTID  trips_rout  route_shor  \
# 0       422        9279           2
# 1       423        9281           4
# 2       424        9282           5
#
#                                            route_url    ShapeSTLen  \
# 0  http://www.cityofmadison.com/metro/routes-sche...  96906.965571
# 1  http://www.cityofmadison.com/metro/routes-sche...  64774.133485
# 2  http://www.cityofmadison.com/metro/routes-sche...  61216.722662
#
#                                             geometry
# 0  MULTILINESTRING ((-89.47360 43.05362, -89.4733...
# 1  MULTILINESTRING ((-89.40392 43.03862, -89.4039...
# 2  MULTILINESTRING ((-89.39414 43.03849, -89.3939...

# %%
colors = [.01*random.randint(0, 70)for i in range(len(routesShapes_df['OBJECTID']))]
routesShapes_df['colors'] = colors
routesShapes_df.head(3)
# Out:
#    OBJECTID  trips_rout  route_shor  \
# 0       422        9279           2
# 1       423        9281           4
# 2       424        9282           5
#
#                                            route_url    ShapeSTLen  \
# 0  http://www.cityofmadison.com/metro/routes-sche...  96906.965571
# 1  http://www.cityofmadison.com/metro/routes-sche...  64774.133485
# 2  http://www.cityofmadison.com/metro/routes-sche...  61216.722662
#
#                                             geometry  colors
# 0  MULTILINESTRING ((-89.47360 43.05362, -89.4733...    0.33
# 1  MULTILINESTRING ((-89.40392 43.03862, -89.4039...    0.16
# 2  MULTILINESTRING ((-89.39414 43.03849, -89.3939...    0.65

# %%
ax = cityShapes_df.plot(color='#e7e3e0', figsize=(12, 12))
lakeShapes_df.plot(color='lightblue', alpha=.9, ax=ax)
streetShapes_df.plot(color='#fbf7f4', alpha=.7, ax=ax)


routesShapes_df.plot(ax=ax, column='colors', cmap='viridis', linestyle="-", alpha=.5, linewidth=3)

plt.xticks([])
plt.yticks([])

ax.set_facecolor("#e7e3e0")
plt.title("Madison Metro System Map", fontsize=18)
plt.savefig('PaperFigures_V2/SystemMap', bbox_inches='tight')
plt.show()

# %%
interesting_points = pd.DataFrame(
    {'Place': ['Capitol', 'Campus', 'AmFam', 'Beltline', 'West'],
     'Latitude': [43.074692, 43.075583, 43.151149, 43.057441, 43.090814],
     'Longitude': [-89.384165, -89.409121, -89.287082, -89.498352, -89.522766]})

interesting_points_gdf = geopandas.GeoDataFrame(interesting_points, geometry=geopandas.points_from_xy(interesting_points.Longitude, interesting_points.Latitude))
interesting_points_gdf
# Out:
#       Place   Latitude  Longitude                    geometry
# 0   Capitol  43.074692 -89.384165  POINT (-89.38416 43.07469)
# 1    Campus  43.075583 -89.409121  POINT (-89.40912 43.07558)
# 2     AmFam  43.151149 -89.287082  POINT (-89.28708 43.15115)
# 3  Beltline  43.057441 -89.498352  POINT (-89.49835 43.05744)
# 4      West  43.090814 -89.522766  POINT (-89.52277 43.09081)

# %%
fig, ax = plt.subplots(1, 1, figsize=(16, 16))
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=-1.5)

ax = df_dane.plot(column='Population', ax=ax, legend=True, legend_kwds={'label': "log of Population Denstiy"}, cax=cax, cmap='viridis_r', alpha=1)
fig = ax.figure
cb_ax = fig.axes[1]
cb_ax.tick_params(length=0)

lakeShapes_df.plot(color='lightblue', alpha=.9, ax=ax)
streetShapes_df.plot(color='#fbf7f4', alpha=.1, ax=ax)
interesting_points_gdf.plot(color='#be0119', alpha=1.0, ax=ax, zorder=2, markersize=50)

routesShapes_df.plot(ax=ax, colors='white', linestyle="-", alpha=1, linewidth=1.0, zorder=1)
cax.set_yticklabels([])
cax.set_ylabel("log of Population Denstiy (arb.)", fontsize=16)


ax.set_facecolor("#e7e3e0")
ax.set_xlim(-89.59, -89.23)
ax.set_ylim(42.98, 43.19)
ax.set_yticks([])
ax.set_xticks([])

plt_ax = fig.axes[0]
plt_ax.annotate("Capitol", (.583, .42), fontsize=16, color='#be0119', xycoords='axes fraction')
plt_ax.annotate("Campus", (.461, .48), fontsize=16, color='#be0119', xycoords='axes fraction')


fig.suptitle("Population Density and Madison Metro Routes", fontsize=18, x=.55, y=.765)
plt.savefig('PaperFigures_V2/PopDenstiyRoutes', bbox_inches='tight')
plt.savefig('PaperFigures_V2/PopDenstiyRoutes', bbox_inches='tight', format='svg')
plt.show()
